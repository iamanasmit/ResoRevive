# %%
import cv2
import os
import numpy as np

def load_images_from_directory(directory, target_size=(100, 100)):
    images = []
    filenames = sorted([f for f in os.listdir(directory) if f.endswith(".jpg") or f.endswith(".png")])
    for filename in filenames:
        img_path = os.path.join(directory, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
            img_resized = cv2.resize(img_rgb, target_size)  
            images.append(img_resized)
    return np.array(images)

# %%
hr_images=load_images_from_directory('/kaggle/input/my-div2k-dataset/DIV2K_train_HR', (400, 400))
lr_images=load_images_from_directory('/kaggle/input/my-div2k-dataset/DIV2K_train_LR_bicubic/X4')

# %%
from keras.models import Model
from keras import Layer
from keras.layers import Dense, Conv2D, PReLU, BatchNormalization, Input, Add, Flatten, Dropout
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-07-29 20:12:17.967658: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-29 20:12:17.967775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-29 20:12:18.144821: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
LR= (100, 100, 3)
HR= (400, 400, 3)

# %%
def build_discriminator():
    input_layer = Input(shape=(25, 25, 512))    
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same')(input_layer)
    x = PReLU()(x)    
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)     
    x = Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)    
    x = Conv2D(filters=128, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)    
    x = Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)    
    x = Conv2D(filters=256, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)    
    x = Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)     
    x = Conv2D(filters=512, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)     
    x = Flatten()(x)
    x = Dense(units=1024)(x)
    x = PReLU()(x)    
    x = Dense(units=1, activation='sigmoid')(x)    
    model = Model(inputs=input_layer, outputs=x)
    return model

# %%
class MyLayer(Layer):
    def call(self, x):
        return tf.nn.depth_to_space(x, block_size=2)
def build_generator():
    input_layer= Input(shape= LR) #LR= (100, 100, 3), the low resolution image
    x=Conv2D(filters= 64, kernel_size=(9,9), strides=(1,1), padding='same')(input_layer)
    x=PReLU()(x)
    x_shortcut=x
    def add_residual_blocks(input_tensor):
        original_tensor=input_tensor
        input_tensor=Conv2D(filters= 64, kernel_size=(3,3), strides=(1,1), padding='same')(input_tensor)
        input_tensor=BatchNormalization()(input_tensor)
        input_tensor=PReLU()(input_tensor)
        input_tensor=Conv2D(filters= 64, kernel_size=(3,3), strides=(1,1), padding='same')(input_tensor)
        input_tensor=BatchNormalization()(input_tensor)
        input_tensor=Add()([original_tensor, input_tensor])
        return input_tensor
    for i in range(5):
        x=add_residual_blocks(x)
    x=Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(x)
    x=BatchNormalization()(x)
    x=Add()([x, x_shortcut])
    x=Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(x)
    x=MyLayer()(x)#hardcoded function to increase width and height by reducing number of channels
    x=PReLU()(x)
    x=Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(x)
    x=MyLayer()(x)#hardcoded function to increase width and height by reducing number of channels
    x=PReLU()(x)
    x=Conv2D(filters=3, kernel_size=(9,9), strides=(1,1), padding='same')(x)
    model=Model(inputs=input_layer, outputs=x)
    return model

# %%
from tensorflow.keras.applications import VGG19
def build_vgg():
    vgg = VGG19(weights="imagenet", include_top=False, input_shape=HR)
    vgg.trainable = False
    model = Model(inputs=vgg.input, outputs=vgg.get_layer("block5_conv4").output)
    return model

# %%
def combine(generator, discriminator, vgg):
    discriminator.trainable= False
    input_lr= Input(shape=(100, 100, 3))
    gen_hr=generator(input_lr)
    gen_hr_features=vgg(gen_hr)
    validity=discriminator(gen_hr_features)
    model = Model(inputs=input_lr, outputs=[validity, gen_hr_features])
    model.compile(
        loss=['binary_crossentropy', 'mse'],
        loss_weights=[1e-3, 1],
        optimizer=Adam(0.0002, 0.5)
    )
    return model

# %%
import matplotlib.pyplot as plt

# %%
from keras import backend as K
import gc
def train(g_model, vgg, d_model, srgan, batch_size=100, epochs=5):
    half_batch_size=int(batch_size/2)
    batches=int(lr_images.shape[0]/batch_size)
    d_model.compile(loss='binary_crossentropy', optimizer='adam')
    c=0
    for epoch in range(epochs):
        print(f'epoch number {epoch+1} has started')
        for batch in range(batches):
            c=c+1
            idx = np.random.randint(0, lr_images.shape[0], half_batch_size)
            
            real_hr_images=hr_images[idx]
            real_hr_features=vgg.predict(real_hr_images)
            real_image_label=np.ones(half_batch_size)
            d_loss_real=d_model.train_on_batch(real_hr_features, real_image_label)
            
            fake_hr_images=g_model.predict(lr_images[idx])
            fake_hr_features=vgg.predict(fake_hr_images)
            fake_image_label=np.zeros(half_batch_size)
            d_loss_fake=d_model.train_on_batch(fake_hr_features, fake_image_label)
            
            indices = np.random.randint(0, lr_images.shape[0], batch_size)    
            images_lr=lr_images[indices]
            images_hr=hr_images[indices]
            images_hr_features=vgg.predict(images_hr)
            gan_label=np.ones(batch_size)
            g_loss=srgan.train_on_batch(images_lr, [gan_label, images_hr_features])
            
            print(f'epoch={epoch+1} batch={batch+1} d_loss on real={d_loss_real} d_loss on fake={d_loss_fake} g_loss={g_loss}')
            
            if (c%100==0):
                img_hr=g_model.predict(lr_images[7])
                plt.imshow(lr_images[7])
                plt.show()
                plt.imshow(hr_images[7])
                plt.show()
            K.clear_session()
            gc.collect()

# %%
discriminator=build_discriminator()
generator=build_generator()
vgg=build_vgg()
srgan=combine(generator, discriminator, vgg)
train(generator, vgg, discriminator, srgan)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# epoch number 1 has started
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1:23 84s/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722284035.900957     109 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 137s 53s/step
# /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# W0000 00:00:1722284097.721772     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2024-07-29 20:15:05.344368: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:15:05.489872: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.14559615s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:15:09.455988: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:15:09.603941: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.148060936s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 8s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 858ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step
# 2024-07-29 20:16:18.834374: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:19.145393: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.311138557s
# Trying algorithm eng18{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:20.145582: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:20.533547: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.388060293s
# Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:21.533740: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:21.959401: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.425756494s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:22.959626: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:23.398841: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.439317344s
# Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:24.399040: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:25.915372: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.516426452s
# Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:26.915627: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:29.495362: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.579859854s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:31.229352: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:31.564613: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.335354095s
# Trying algorithm eng18{k2=1,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:32.564933: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:32.959967: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.395255223s
# Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:33.960236: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:34.394635: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.434570337s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:35.394869: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:35.842814: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.448077574s
# Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:36.843101: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:38.372035: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.529109191s
# Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:39.372341: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:41.972331: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.600169159s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,3,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[3,16,9,9]{3,2,1,0}, f32[3]{0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:57.790909: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:57.860581: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.069774124s
# Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:58.860778: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:58.975072: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.114393699s
# Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:16:59.975274: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:00.091562: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.116393461s
# Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:01.091817: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=0,k4=2,k5=1,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:01.456403: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.364687628s
# Trying algorithm eng20{k2=0,k4=2,k5=1,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:02.456599: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:02.845681: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.389177859s
# Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:03.845894: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:04.752986: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.907196766s
# Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:05.753197: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:06.615223: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.862122202s
# Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:07.615436: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:08.565307: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.949978765s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:09.565521: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:10.675753: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.11033273s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:11.675973: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:12.816632: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.140757556s
# Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:13.816852: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:15.821078: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.004335395s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:20.191015: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:20.271518: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.080616276s
# Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:21.271707: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:21.394566: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.122952731s
# Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:22.394759: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:22.517525: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.122862465s
# Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:23.517773: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=0,k4=2,k5=1,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:23.888944: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.371268815s
# Trying algorithm eng20{k2=0,k4=2,k5=1,k6=0,k7=0,k19=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:24.889132: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:25.287896: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.398856228s
# Trying algorithm eng18{k2=0,k4=3,k5=1,k6=0,k7=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:26.288086: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:27.209490: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.921491585s
# Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:28.209782: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:29.085109: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.875505902s
# Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:30.085314: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:31.047450: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.962235287s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:32.047656: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:33.170100: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.122544119s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:34.170317: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:35.321806: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.151595812s
# Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:36.322025: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:17:38.344467: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.022522752s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[100,64,400,400]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,400,400]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:05.291321: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:05.334581: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.043371424s
# Trying algorithm eng20{k2=2,k4=1,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:06.334794: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2,k4=2,k5=3,k6=2,k7=1} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:06.421616: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.086932177s
# Trying algorithm eng19{k2=2,k4=2,k5=3,k6=2,k7=1} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:07.421819: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:07.504567: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.082847757s
# Trying algorithm eng20{k2=2,k4=2,k5=0,k6=0,k7=0,k19=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:08.504782: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:08.589309: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.084644985s
# Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:09.589552: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:09.763482: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.174056313s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:10.763692: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:10.956275: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.192685458s
# Trying algorithm eng11{k2=0,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:11.956562: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:12.841751: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.885361184s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:13.841995: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:14.685629: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.843743153s
# Trying algorithm eng11{k2=3,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:15.685881: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:18:16.509909: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.824143811s
# Trying algorithm eng35{k2=4,k3=0} for conv (f32[100,128,200,200]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,128,200,200]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# ...
# 2024-07-29 20:24:46.072503: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=8,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:46.615237: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.542912233s
# Trying algorithm eng1{k2=8,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:47.615450: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng21{k2=2,k4=3,k5=0,k6=0,k7=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:47.925202: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.309868009s
# Trying algorithm eng21{k2=2,k4=3,k5=0,k6=0,k7=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:48.925417: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=0,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:51.998964: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.073663501s
# Trying algorithm eng20{k2=0,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:52.999248: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=5,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:56.151769: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.152710751s
# Trying algorithm eng1{k2=5,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:24:57.152057: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=2,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:25:02.596512: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.444634244s
# Trying algorithm eng1{k2=2,k3=0} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:25:03.596785: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-07-29 20:25:06.439298: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.842686111s
# Trying algorithm eng0{} for conv (f32[3,16,9,9]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,16,400,400]{3,2,1,0}, f32[100,3,400,400]{3,2,1,0}), window={size=9x9 pad=4_4x4_4}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# W0000 00:00:1722284707.188888     106 hlo_rematerialization.cc:2946] Can't reduce memory use below 10.91GiB (11715992180 bytes) by rematerialization; only reduced to 27.32GiB (29330289952 bytes), down from 30.51GiB (32765717272 bytes) originally
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[11], line 5
#       3 vgg=build_vgg()
#       4 srgan=combine(generator, discriminator, vgg)
# ----> 5 train(generator, vgg, discriminator, srgan)
#
# Cell In[10], line 29, in train(g_model, vgg, d_model, srgan, batch_size, epochs)
#      27 images_hr_features=vgg.predict(images_hr)
#      28 gan_label=np.ones(batch_size)
# ---> 29 g_loss=srgan.train_on_batch(images_lr, [gan_label, images_hr_features])
#      31 print(f'epoch={epoch+1} batch={batch+1} d_loss on real={d_loss_real} d_loss on fake={d_loss_fake} g_loss={g_loss}')
#      33 if (c%100==0):
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:544, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     541 def data():
#     542     yield (x, y, sample_weight)
# --> 544 logs = self.train_function(data())
#     545 logs = tree.map_structure(lambda x: np.array(x), logs)
#     546 if return_dict:
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/opt/conda/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/opt/conda/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 701, in start
#
#   File "/opt/conda/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/opt/conda/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/opt/conda/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "/opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/tmp/ipykernel_34/1656504635.py", line 5, in <module>
#
#   File "/tmp/ipykernel_34/3582195680.py", line 29, in train
#
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 544, in train_on_batch
#
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
# Out of memory while trying to allocate 29760683584 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:  314.74MiB
#               constant allocation:        20B
#         maybe_live_out allocation:   85.99MiB
#      preallocated temp allocation:   27.72GiB
#   preallocated temp fragmentation:  496.56MiB (1.75%)
#                  total allocation:   28.02GiB
#               total fragmentation:  498.24MiB (1.74%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 4.81GiB
# 		Operator: op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_3_1/functional_2_1/block3_conv4_1/convolution/Conv2DBackpropInput" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: u8[5170397184]
# 		==========================
#
# 	Buffer 2:
# 		Size: 3.81GiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block1_conv2_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,64,400,400]
# 		==========================
#
# 	Buffer 3:
# 		Size: 3.81GiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block1_conv1_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,64,400,400]
# 		==========================
#
# 	Buffer 4:
# 		Size: 1.91GiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block2_conv2_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,128,200,200]
# 		==========================
#
# 	Buffer 5:
# 		Size: 1.91GiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block2_conv1_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,128,200,200]
# 		==========================
#
# 	Buffer 6:
# 		Size: 976.56MiB
# 		Operator: op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_3_1/functional_2_1/block3_conv4_1/convolution/Conv2DBackpropInput" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,256,100,100]
# 		==========================
#
# 	Buffer 7:
# 		Size: 976.56MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/functional_3_1/functional_2_1/block3_conv4_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[100,256,100,100]
# 		==========================
#
# 	Buffer 8:
# 		Size: 976.56MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block3_conv3_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,256,100,100]
# 		==========================
#
# 	Buffer 9:
# 		Size: 976.56MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block3_conv2_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,256,100,100]
# 		==========================
#
# 	Buffer 10:
# 		Size: 976.56MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_2_1/block3_conv1_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,256,100,100]
# 		==========================
#
# 	Buffer 11:
# 		Size: 976.56MiB
# 		Operator: op_type="AddV2" op_name="functional_3_1/functional_1_1/p_re_lu_16_1/add" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: fusion
# 		Shape: f32[100,16,400,400]
# 		==========================
#
# 	Buffer 12:
# 		Size: 976.56MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_1_1/conv2d_21_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,64,200,200]
# 		==========================
#
# 	Buffer 13:
# 		Size: 244.14MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_1_1/conv2d_19_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,64,100,100]
# 		==========================
#
# 	Buffer 14:
# 		Size: 244.14MiB
# 		Operator: op_type="AddV2" op_name="functional_3_1/functional_1_1/add_4_1/Add" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160 deduplicated_name="fusion.377"
# 		XLA Label: fusion
# 		Shape: f32[100,64,100,100]
# 		==========================
#
# 	Buffer 15:
# 		Size: 244.14MiB
# 		Operator: op_type="Conv2D" op_name="functional_3_1/functional_1_1/conv2d_18_1/convolution" source_file="/opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1160
# 		XLA Label: custom-call
# 		Shape: f32[100,64,100,100]
# 		==========================
#
#
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_iterator_16957]
